# %%
# -------------------------------------------------
# File evaluation - Roberto Schlatter
# 15-10-2020
#-------------------------------------------------
import pandas as pd
import os
    
rootdir = '/Users/SCHLARO4/1_PRIVATE/Prog/Private/'

sFilename = 'transactions-28092020.csv'

df_transactions = pd.read_csv(sFilename, sep=';', encoding= 'unicode_escape')

lst_header = ['Transaktionen', 'Name']

#----------
# DIVIDENDE
#----------
# Filter table to show only columns "Transaktionen", "Name"
df_dividende = df_transactions[df_transactions['Transaktionen'].isin(['Dividende'])]

df_dividende["Nettobetrag"] = pd.to_numeric(df_Dividende["Nettobetrag"])

# Final dataframe for dividends
df_export_dividende = df_dividende.groupby(lst_header)['Nettobetrag'].sum()

print("Dividende: ", df_export_dividende)

#-------
#KOSTEN
#-------
# KAUF & VERKAUF Kosten
df_kosten = df_transactions[df_transactions['Transaktionen'].isin(['Kauf', 'Verkauf', 'Dividende'])]

# Final dataframe for costs
df_export_kosten = df_kosten.groupby(lst_header)['Kosten'].sum()

print("total kosten: ", df_Export_Kosten_New)
# Out:
# Dividende:  Transaktionen  Name
# Dividende      AMERICAN EXPRESS ORD                27.39
#                AMS                                 38.08
#                APPLE ORD                          142.46
#                ISHARES 20 PLS YEAR TREASURY B     152.56
#                MICROSOFT ORD                       42.12
#                NVIDIA ORD                          12.82
#                PARTNERS GROUP N                   220.35
#                QUALCOMM ORD                       101.66
#                ROCHE GS                          1091.02
#                SPDR S&P 500 ETF                    43.50
#                UBSETF SMIM CHF DIS                 43.79
#                VANGUARD TOTAL STOCK MARKET ET     187.84
#                Vanguard All World ETF Dist        155.81
#                Vanguard EM ETF Dist               140.84
#                WASTE MANAGEMENT ORD                27.86
#                X NIKKEI 225 ETF                   140.08
#                iSh $ TreasBnd 7-10 USD Dis         24.72
# Name: Nettobetrag, dtype: float64
# total kosten:  Transaktionen  Name
# Dividende      AMERICAN EXPRESS ORD               11.74
#                AMS                                14.45
#                APPLE ORD                          61.06
#                ISHARES 20 PLS YEAR TREASURY B     65.41
#                MICROSOFT ORD                      18.06
#                NVIDIA ORD                          5.54
#                PARTNERS GROUP N                  118.65
#                QUALCOMM ORD                       43.56
#                ROCHE GS                          587.48
#                SPDR S&P 500 ETF                    0.00
#                UBSETF SMIM CHF DIS                23.59
#                VANGUARD TOTAL STOCK MARKET ET     80.51
#                Vanguard All World ETF Dist         0.00
#                Vanguard EM ETF Dist                0.00
#                WASTE MANAGEMENT ORD               11.93
#                X NIKKEI 225 ETF                    0.00
#                iSh $ TreasBnd 7-10 USD Dis         0.00
# Kauf           AC IMMUNE SA ORD                   26.23
#                ALPHABET CL C ORD                 113.00
#                AMAZON COM ORD                    115.41
#                AMERICAN EXPRESS ORD               59.27
#                AMS                                24.80
#                APPLE ORD                         223.60
#                ASML HOLDING ORD                   38.50
#                Alibaba Grp                        36.35
#                BLACKBERRY ORD                     26.59
#                BLUEBIRD BIO ORD                   26.11
#                CLOUDFLARE CL A ORD                38.69
#                DIAGEO ORD                         34.82
#                FIAT CHRYSLER AUTOMOBILES ORD     110.73
#                                                   ...
# Verkauf        INMODE ORD                         41.75
#                ISHARES 20 PLS YEAR TREASURY B     75.64
#                KANDI TECHNOLOGIES GROUP ORD        2.91
#                LAFARGEHOLCIM N                    39.95
#                MICROSOFT ORD                      16.17
#                NESTLE N                           42.25
#                NVIDIA ORD                        139.03
#                OBSEVA ORD                         53.60
#                PANTAFLIX ORD                      26.77
#                PARTNERS GROUP N                   80.95
#                QUALCOMM ORD                       48.70
#                ROCHE GS                           98.35
#                SHOPIFY CL A SUB VTG ORD            6.01
#                SIKA N                              7.20
#                SPDR MSCI ACWI                     24.40
#                SPDR S&P 500 ETF                   59.00
#                SPDR S&P 500 UCITS ETF Dist        48.10
#                STADLER RAIL N                     11.40
#                SWISS RE N                         80.35
#                TESLA ORD                          69.11
#                UBSETF GOLD USD DIS                12.05
#                UBSETF SMIM CHF DIS                13.20
#                VANGUARD TOTAL STOCK MARKET ET     14.93
#                VAT GROUP N                        23.80
#                Vanguard EM ETF Dist               11.90
#                WASTE MANAGEMENT ORD                8.37
#                X MSCI CHINA                       46.85
#                X NIKKEI 225 ETF                   72.02
#                ZOOM VIDEO COMMUNICATIONS CL A      8.39
#                iSh $ TreasBnd 7-10 USD Dis        14.93
# Name: Kosten, Length: 105, dtype: float64
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
value = -1
filenames = []
myvals = []
mydate = []
mycycle = []
mytime = []
myfolder = []
myoffset = []
rootdir = '/Users/SCHLARO4/1_PRIVATE/Prog/Private/'

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file

        if not filepath.endswith(".csv"):
            continue
        
        filenames.append(file) 
        track = subdir.split('/')
        myfolder.append(track[len(track)-1])
        with open(filepath, 'r') as ifs:
            for line in ifs:
                line = line.strip()
               
                if line.startswith('Date'):
                    tokens = line.split(';')
                    date = tokens[1]
                    mydate.append(date)     
                if line.startswith('Time'):
                    tokens = line.split(';')
                    time = tokens[1]
                    mytime.append(time)
                
                if line.startswith('Cycle number'):
                    tokens = line.split(';')
                    cycle = int(tokens[1])
                    mycycle.append(cycle)
                
                if line.startswith('Tara Y offset'):
                    tokens = line.split(';')
                    offset = tokens[1]
                    myoffset.append(offset)
                                
                if line.startswith('Peak-peak Y'):             
                    # Here we have the right line
                    tokens = line.split(';')
                    value = float(tokens[1].replace(',', '.'))
                    myvals.append(value)
                    break
# combine all lists in one tuple                    
tuples_combined = list(zip(myfolder, filenames, myvals, myoffset, mydate, mytime, mycycle))         

# create dataframe from tuple
df_whole = pd.DataFrame(tuples_combined, columns = ['Track','Filenames','Peak-peak Y [N]', 'Offset Y [N]','Date','Time','Cycle'] )

# provide summary of statistics grouped by "track" column
df_stat = df_whole.groupby('Track')['Peak-peak Y [N]'].describe()

# store statistics summary in Excel
df_stat.to_excel('summary_results.xlsx')

# store whole dataframe in Excel
df_whole.to_excel('results.xlsx')

print(df_stat)

plt = df_whole['Peak-peak Y [N]']
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-6614ad5aad1c> in <module>
#      56
#      57 # provide summary of statistics grouped by "track" column
# ---> 58 df_stat = df_whole.groupby('Track')['Peak-peak Y [N]'].describe()
#      59
#      60 # store statistics summary in Excel
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in describe(self, **kwargs)
#    1081         if self.axis == 1:
#    1082             return result.T
# -> 1083         return result.unstack()
#    1084
#    1085     def value_counts(self, normalize=False, sort=True, ascending=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3299         """
#    3300         from pandas.core.reshape.reshape import unstack
# -> 3301         return unstack(self, level, fill_value)
#    3302
#    3303     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     394         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     395                                fill_value=fill_value,
# --> 396                                constructor=obj._constructor_expanddim)
#     397         return unstacker.get_result()
#     398
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#      96             raise ValueError('must pass column labels for multi-column data')
#      97
# ---> 98         self.index = index.remove_unused_levels()
#      99
#     100         self.level = self.index._get_level_number(level)
#
# AttributeError: 'Index' object has no attribute 'remove_unused_levels'
